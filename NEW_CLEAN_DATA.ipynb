# %%
import pandas as pd
import csv
import numpy as np

# %% [markdown]
# # cleaning the data

# %% [markdown]
# cleaning the data
# first of all we fill the data with NaN where there was no data or data that we dont need, after this we will make the data type to float(in the original it was an object type data) and then delete the rows that there is to many missing data. becouse the 4 data:beer consumbtion,wine consumption,spirits consumption and alcohol consumption have the same structure we will make a function that does all this to the four datasets.

# %%
def cleaning_data_format_1(df):
    df=df.loc[:, df.columns != 'Unnamed: 0']
    df=df.loc[:, df.columns != 'Latest dataavailable']
    for column in df.iloc[:,1:]:
        df[column] = df[column].replace(['-'],np.NaN)
    for column in df.iloc[:,1:]:
        df[column] = df[column].astype(float) 
    #df=df.rename({'Unnamed: 0.1':'country'},axis='columns')
    return df

# %% [markdown]
# ## first data is: Beer

# %%
Beer_df = pd.read_csv(r"data\list_of_BEER_consumption.csv")
Beer_df.head(4)
# Out:
#    Unnamed: 0 Unnamed: 0.1 Latest dataavailable 2018 2017 2016 2015 2014 2013  \
# 0           0      Albania                  1.6  1.6  1.6  1.5  1.5  1.3  1.3
# 1           1      Andorra                  3.7  3.7  3.5  3.4  3.3  3.3    3
# 2           2      Armenia                  0.5  0.5  0.5  0.4  0.5  0.5  0.4
# 3           3      Austria                  6.4  6.4  6.2  6.2    6  6.3    6
#
#   2012  ... 1969 1968 1967 1966 1965 1964 1963 1962 1961 1960
# 0  1.3  ...  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5    -    -
# 1  3.1  ...    -    -    -    -    -    -    -    -    -    -
# 2  0.3  ...    -    -    -    -    -    -    -    -    -    -
# 3  6.3  ...  6.4  6.8  6.5  6.5    6    6  5.5  5.2  4.9  4.7
#
# [4 rows x 62 columns]

# %%
Clean_Beer_data=cleaning_data_format_1(Beer_df)

# %%
Clean_Beer_data
# Out:
#                                          Unnamed: 0.1  2018  2017  2016  2015  \
# 0                                             Albania   1.6   1.6   1.5   1.5
# 1                                             Andorra   3.7   3.5   3.4   3.3
# 2                                             Armenia   0.5   0.5   0.4   0.5
# 3                                             Austria   6.4   6.2   6.2   6.0
# 4                                          Azerbaijan   0.3   0.3   0.2   0.3
# ..                                                ...   ...   ...   ...   ...
# 57                 Commonwealth of Independent States   2.4   2.3   2.5   2.6
# 58  Central Asian Republics Information Network me...   1.0   1.0   0.9   0.9
# 59  South-eastern Europe Health Network members (S...   3.7   3.7   3.6   3.5
# 60                                   Nordic countries   3.1   3.1   3.2   3.1
# 61                                    Small countries   3.4   3.4   3.4   3.4
#
# ...

# %%
Clean_Beer_data.to_csv(r"data\Clean_Beer_data.csv")

# %% [markdown]
# # SECOND IS WINE

# %%
WINE_consumption = pd.read_csv(r"data\list_of_wine_consumption.csv")
Clean_WINE_data=cleaning_data_format_1(WINE_consumption)
Clean_WINE_data.to_csv(r'data\Clean_WINE_data.csv')
Clean_WINE_data
# Out:
#                                          Unnamed: 0.1  2018  2017  2016  2015  \
# 0                                             Albania   1.3   1.3   1.3   1.1
# 1                                             Andorra   3.7   4.0   4.0   4.1
# 2                                             Armenia   0.4   0.4   0.3   0.2
# 3                                             Austria   3.6   3.6   3.7   3.6
# 4                                          Azerbaijan   0.1   0.1   0.2   0.1
# ..                                                ...   ...   ...   ...   ...
# 57                 Commonwealth of Independent States   0.8   0.7   0.7   0.7
# 58  Central Asian Republics Information Network me...   0.2   0.2   0.2   0.2
# 59  South-eastern Europe Health Network members (S...   2.0   2.0   1.8   1.8
# 60                                   Nordic countries   3.0   3.0   3.0   3.0
# 61                                    Small countries   3.0   3.0   3.0   2.9
#
# ...

# %% [markdown]
# ## THIRD IS SPIRIT DRINK'S

# %%
SPIRITS_consumption = pd.read_csv(r"data\list_of_SPIRITS_consumption.csv")
Clean_SPIRIT_data=cleaning_data_format_1(SPIRITS_consumption)
Clean_SPIRIT_data.to_csv(r'data\Clean_SPIRIT_data.csv')
Clean_SPIRIT_data
# Out:
#                                          Unnamed: 0.1  2018  2017  2016  2015  \
# 0                                             Albania   1.7   1.8   1.8   1.9
# 1                                             Andorra   2.3   2.3   2.4   2.3
# 2                                             Armenia   2.8   3.0   3.1   3.3
# 3                                             Austria   1.9   1.9   1.9   1.9
# 4                                          Azerbaijan   2.5   2.5   2.7   3.7
# ..                                                ...   ...   ...   ...   ...
# 57                 Commonwealth of Independent States   2.6   2.5   2.9   3.0
# 58  Central Asian Republics Information Network me...   1.2   1.2   1.3   1.3
# 59  South-eastern Europe Health Network members (S...   2.1   2.1   2.1   2.0
# 60                                   Nordic countries   1.2   1.2   1.2   1.2
# 61                                    Small countries   2.8   2.8   2.8   2.8
#
# ...

# %% [markdown]
# ## FOURTH IS PURE ALCOHOL DRINK'S

# %%
PURE_ALCOHOL_consumption = pd.read_csv(r"data\list_of_PURE_ALCOHOL_consumption.csv")
CLEAN_PURE_ALCOHOL_DATA=cleaning_data_format_1(PURE_ALCOHOL_consumption)
CLEAN_PURE_ALCOHOL_DATA.to_csv(r'data\CLEAN_PURE_ALCOHOL_DATA.csv')
CLEAN_PURE_ALCOHOL_DATA
# Out:
#                                          Unnamed: 0.1  2018  2017  2016  2015  \
# 0                                             Albania   4.7   4.8   4.7   4.5
# 1                                             Andorra   9.8   9.9   9.9   9.8
# 2                                             Armenia   3.7   3.8   3.8   4.0
# 3                                             Austria  11.8  11.7  11.7  11.6
# 4                                          Azerbaijan   2.9   2.9   3.0   4.1
# ..                                                ...   ...   ...   ...   ...
# 57                 Commonwealth of Independent States   5.8   5.6   6.2   6.4
# 58  Central Asian Republics Information Network me...   2.3   2.4   2.4   2.4
# 59  South-eastern Europe Health Network members (S...   7.9   7.9   7.5   7.4
# 60                                   Nordic countries   7.7   7.6   7.7   7.7
# 61                                    Small countries   9.3   9.3   9.3   9.1
#
# ...

# %% [markdown]
# his clean the data of csv file that we download. This csv include data of death diseases cases in all countries of the world. We want to rescue data about Liver diseases. Most diseases are caused by heavy drinking of alcohol.

# %% [markdown]
# ## Deaths

# %%
deaths_by_cause = pd.read_csv(r"data\annual-number-of-deaths-by-cause (1).csv")

# %%
def cleaning_data_format_2(df):
    df1=df[['Entity','Year','Deaths - Alcohol use disorders - Sex: Both - Age: All Ages (Number)','Deaths - Cirrhosis and other chronic liver diseases - Sex: Both - Age: All Ages (Number)']]
    df1=df1.rename({'Entity':'country'},axis='columns')
    for column in df1.iloc[:,2:]:
        df1[column] = df1[column].astype(float)
    return df1

# %%
CLEAN_eaths_becouse_alcohol_DATA=cleaning_data_format_2(deaths_by_cause)

# %%
CLEAN_eaths_becouse_alcohol_DATA.to_csv(r"data\CLEAN_eaths_becouse_alcohol_DATA.csv")
CLEAN_eaths_becouse_alcohol_DATA
# Out:
#           country  Year  \
# 0     Afghanistan  2007
# 1     Afghanistan  2008
# 2     Afghanistan  2009
# 3     Afghanistan  2011
# 4     Afghanistan  2012
# ...           ...   ...
# 6681     Zimbabwe  2013
# 6682     Zimbabwe  2014
# 6683     Zimbabwe  2015
# 6684     Zimbabwe  2016
# 6685     Zimbabwe  2017
#
#       Deaths - Alcohol use disorders - Sex: Both - Age: All Ages (Number)  \
# 0                                             96.027592
# 1                                             98.308461
# 2                                            100.088778
# 3                                            105.565020
# 4                                            108.281688
# ...                                                 ...
# 6681                                          73.649954
# 6682                                          73.460128
# 6683                                          74.605887
# 6684                                          75.907792
# ...
